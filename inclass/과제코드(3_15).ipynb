# %% [markdown]
# <a href="https://colab.research.google.com/github/chaehyewon/2024-1-Machine-Learning/blob/main/inclass/%EA%B3%BC%EC%A0%9C%EC%BD%94%EB%93%9C(3_15).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 온실 가스 배출량과 기온 상승:
#
# 가정: 온실 가스 배출량과 기온 상승 사이에는 선형 관계가 있다.
# 데이터: 여러 해에 걸친 온실 가스 배출량과 기온 상승률 데이터를 수집.
# 목표: 온실 가스 배출량을 통해 미래의 기온 상승률을 예측.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# 가상의 데이터 생성
np.random.seed(0)  # 일관된 결과를 위해 난수 발생 시드 설정

# 온실 가스 배출량과 기온 상승률 사이에 선형 관계 설정
# y = 0.5 * x + 2 + 노이즈
n_samples = 100
greenhouse_gas_emissions = np.random.uniform(50, 200, n_samples).reshape(-1, 1)  # 50 ~ 200 사이의 값을 가진 100개의 데이터 생성
temperature_increase = 0.5 * greenhouse_gas_emissions + 2 + np.random.normal(0, 5, n_samples).reshape(-1, 1)  # 기온 상승률 생성 (노이즈 추가)

# 시각화
plt.scatter(greenhouse_gas_emissions, temperature_increase)
plt.xlabel("Greenhouse Gas Emissions")
plt.ylabel("Temperature Increase")
plt.title("Relationship between Greenhouse Gas Emissions and Temperature Increase")
plt.grid(True)
plt.show()

# 선형 회귀 모델 학습
model = LinearRegression()
model.fit(greenhouse_gas_emissions, temperature_increase)

# 새로운 값을 예측
new_emission = np.array([[180]])  # 새로운 온실 가스 배출량 값
predicted_temperature_increase = model.predict(new_emission)

print("Predicted Temperature Increase:", predicted_temperature_increase[0][0])
# Out:
# Predicted Temperature Increase: 92.83747381331168

# %%
## 수업 ppt에 있는 코드

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
x = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

model = LinearRegression()

model.fit(x, y)

X_new = [[37_655.2]]
print(model.predict(X_new))
# Out:
# [[6.30165767]]

# %%
## 수업 ppt

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression


lifesat = pd.read_csv("data.csv")
x = lifesat[["dist"]].values
y = lifesat[["won"]].values

lifesat.plot(kind='scatter', grid=True,
             x="dist", y="won")
plt.axis([0, 12, 0, 35000])
plt.show()

model = LinearRegression()

model.fit(x, y)

X_new = [[8]]
print(model.predict(X_new))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-02a7984fd948> in <cell line: 8>()
#       6
#       7
# ----> 8 lifesat = pd.read_csv("data.csv")
#       9 x = lifesat[["dist"]].values
#      10 y = lifesat[["won"]].values
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# ##
# dist,won
# 1,2000
# 2,4000
# 3,5500
# 5,12000
# 7,1000
# 8.5,18000
# 10,21500

# %% [markdown]
# 온실 가스 배출량과 기온 상승을 (x, y)로 표기했을 때, 10가지 예시를 드리겠습니다.
#
# (100, 52)
# (120, 59)
# (140, 66)
# (160, 73)
# (180, 80)
# (200, 87)
# (220, 94)
# (240, 101)
# (260, 108)
# (280, 115)
# 이 예시들은 온실 가스 배출량(x)에 따른 기온 상승(y)을 나타내는 값으로, 선형 관계를 따르는 가상의 데이터입니다.

# %% [markdown]
# Greenhouse Gas Emissions,Temperature Increase
# 100, 52
# 120, 59
# 140, 66
# 160, 73
# 180, 80
# 200, 87
# 220, 94
# 240, 101
# 260, 108
# 280, 115

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# 데이터 불러오기
lifesat = pd.read_csv("data.csv")

# 독립 변수(x)와 종속 변수(y) 설정
x = lifesat[["Greenhouse Gas Emissions"]].values
y = lifesat[["Temperature Increase"]].values

# 산점도로 데이터 시각화
lifesat.plot(kind='scatter', grid=True, x="Greenhouse Gas Emissions", y="Temperature Increase")
plt.xlabel("Greenhouse Gas Emissions")
plt.ylabel("Temperature Increase")
plt.title("Relationship between Greenhouse Gas Emissions and Temperature Increase")
plt.grid(True)
plt.show()

# 선형 회귀 모델 학습
model = LinearRegression()
model.fit(x, y)

# 새로운 값을 예측
X_new = [[180]]  # 새로운 온실 가스 배출량 값
predicted_temperature_increase = model.predict(X_new)

print("Predicted Temperature Increase:", predicted_temperature_increase[0][0])
# Out:
# Predicted Temperature Increase: 80.0

# %% [markdown]
# ## 수치 데이터 예시
#
# Greenhouse Gas Emissions, Temperature Increase
# 500, 0.3
# 1000, 0.6
# 1500, 0.9
# 2000, 1.2
# 2500, 1.5
# 3000, 1.8
# 3500, 2.1
# 4000, 2.4

# %%
## 최종 제출용 코드!!

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# 데이터 불러오기
lifesat = pd.read_csv("data.csv")

# 독립 변수(x)와 종속 변수(y) 설정
x = lifesat[["Greenhouse Gas Emissions"]].values
y = lifesat[["Temperature Increase"]].values

# 산점도로 데이터 시각화
lifesat.plot(kind='scatter', grid=True, x="Greenhouse Gas Emissions", y="Temperature Increase")
plt.xlabel("Greenhouse Gas Emissions")
plt.ylabel("Temperature Increase")
plt.title("Relationship between Greenhouse Gas Emissions and Temperature Increase")
plt.grid(True)
plt.show()

# 선형 회귀 모델 학습
model = LinearRegression()
model.fit(x, y)

# 새로운 값을 예측
X_new = [[4500]]  # 새로운 온실 가스 배출량 값
predicted_temperature_increase = model.predict(X_new)

print("Predicted Temperature Increase:", predicted_temperature_increase[0][0])
# Out:
# Predicted Temperature Increase: 2.6999999999999997
